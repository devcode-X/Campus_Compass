# %%
# === Campus Compass Path Setup (Fixed) ===
import os, sys
from pathlib import Path

# 🧭 Find the actual project root (where src, data, notebook folders exist)
# If running inside /notebook, go one level up.
current = Path.cwd()
if (current / "src").exists():
    ROOT_DIR = current
elif (current.parent / "src").exists():
    ROOT_DIR = current.parent
else:
    # fallback – manually set if above fails
    ROOT_DIR = Path(r"C:\Users\devan\OneDrive\Desktop\campus_compass")

# Change directory to project root
os.chdir(ROOT_DIR)

# Ensure src is importable
sys.path.append(str(ROOT_DIR / "src"))

print("✅ Working directory set to:", os.getcwd())
print("✅ Project root contains:", os.listdir(ROOT_DIR))
print("✅ Data/raw contains:", os.listdir(ROOT_DIR / "data" / "raw"))
# Out:
# ✅ Working directory set to: c:\Users\devan\OneDrive\Desktop\campus_compass
# ✅ Project root contains: ['.env', '.vscode', 'data', 'faiss_index', 'logs', 'notebook', 'README.MD', 'requirements.txt', 'src', 'venv']
# ...

# %%
print('hello')
# Out:
# hello

# %%
import os, requests, json
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path=r"C:\Users\devan\OneDrive\Desktop\campus_compass\.env", override=True)
# Out:
# True

# %%
import os
from dotenv import load_dotenv
load_dotenv()

print("HF_TOKEN:", os.getenv("HF_TOKEN"))
# Out:
# HF_TOKEN: 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

# %%
from src.retriever import hf_llama_inference
print(hf_llama_inference("What is the capital of France?"))
# Out:
# c:\Users\devan\OneDrive\Desktop\campus_compass\src\retriever.py:17: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   emb_model = HuggingFaceEmbeddings(model_name=EMBED_MODEL)
# Bonjour! The capital of France is Paris.

# %%
import os, requests, json
from dotenv import load_dotenv

load_dotenv()

HF_TOKEN = os.getenv("HF_TOKEN")
MODEL = "meta-llama/Meta-Llama-3-8B-Instruct:novita"
HF_CHAT_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {HF_TOKEN}",
    "Content-Type": "application/json"
}

payload = {
    "model": MODEL,
    "messages": [
        {"role": "user", "content": "What is the capital of France?"}
    ],
    "stream": False
}

print("🚀 Sending test request to Hugging Face…")
resp = requests.post(HF_CHAT_URL, headers=headers, json=payload)

if resp.status_code == 200:
    data = resp.json()
    print("✅ Connection successful!")
    print("💬 Model reply:\n", data["choices"][0]["message"]["content"])
else:
    print(f"❌ Request failed with status {resp.status_code}")
    try:
        print(json.dumps(resp.json(), indent=2))
    except Exception:
        print(resp.text)
# Out:
# 🚀 Sending test request to Hugging Face…
# ✅ Connection successful!
# 💬 Model reply:
#  The capital of France is Paris.

# %%
from src.retriever import answer_question

question = "What are the hostel rules and what is the fine for late library books?"
response = answer_question(question)

print("🧩 Question:", question)
print("\n💬 Answer:\n", response["answer"])
print("\n📚 Sources:", response["sources"])
# Out:
# 🧩 Question: What are the hostel rules and what is the fine for late library books?
#
# 💬 Answer:
#  Based on the provided context, I can answer your question.
#
# The hostel rules are not explicitly mentioned in the provided context, but it seems you have the entire Hostel Rules document (PDF) or can extract specific sections for me. However, I can provide some information about the hostel rules from the given snippet:
#
# 1. Curfew timings: Not mentioned.
# 2. Visitor rules: Female members in the boys hostel and male members in the girls hostel are not allowed to visit or stay in the rooms of the student.
# 3. Fines: Not mentioned.
#
# Regarding the fine for late library books, it is not mentioned in the provided context.
#
# 📚 Sources: ['library-rules.pdf:0', 'I found the _Hostel Rules & Regulations_ for RGIPT Jais. HereΓÇÖs a summary of the key points_.txt:2', 'hostelregulations.pdf:8', 'hostelregulations.pdf:13']

# %%
from src.utils import read_pdf
text = read_pdf("data/raw/Revised Notification for Medical Fee Revision.pdf")
print(text[:1000])
# Out:
# 🧠 Initializing OCR engines (TrOCR + EasyOCR)...
# c:\Users\devan\OneDrive\Desktop\campus_compass\venv\Lib\site-packages\transformers\models\auto\modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-small-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ...

# %%
from src.ingest import ingest_all

docs = ingest_all()
print(f"✅ Ingested {len(docs)} chunks including OCR content.")
# Out:
# 🧠 Initializing OCR engines (TrOCR + EasyOCR)...
# c:\Users\devan\OneDrive\Desktop\campus_compass\venv\Lib\site-packages\transformers\models\auto\modeling_auto.py:2284: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-small-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# ...

# %%
from src.embeddings import build_vectorstore
build_vectorstore(persist=True)
# Out:
# 🔹 Using embedding model: sentence-transformers/all-MiniLM-L6-v2
# 📂 Found 27 data files in C:\Users\devan\OneDrive\Desktop\campus_compass\data\raw
# 🔍 OCR fallback on page 1 of Academic Calendar B.Tech.-IDD 2nd & 3rd Year Students, Diploma 2nd & 3rd Year, M.Tech. 2nd Year and PhD All Year.pdf...
# c:\Users\devan\OneDrive\Desktop\campus_compass\venv\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ⚙️ EasyOCR fallback used on page 1.
# 🔍 OCR fallback on page 2 of Academic Calendar B.Tech.-IDD 2nd & 3rd Year Students, Diploma 2nd & 3rd Year, M.Tech. 2nd Year and PhD All Year.pdf...
# ⚙️ EasyOCR fallback used on page 2.
#
# ✅ FINAL OCR OUTPUT (Academic Calendar B.Tech.-IDD 2nd & 3rd Year Students, Diploma 2nd & 3rd Year, M.Tech. 2nd Year and PhD All Year.pdf):
# ...
# zofld ojief} d4RHU gleifId} <ir%ToI
# ...

# %%
from src.retriever import answer_question
questions = [
    "If the academic calendar mentions exam week and the hostel rules restrict late-night entry during that time, what options does a student have for overnight study?"
    
]

for q in questions:
    response = answer_question(q)
    print(f"\n🧩 Q: {q}")
    print(f"💬 {response['answer']}")
    print(f"📚 {response['sources']}")
    print("=" * 80)
# Out:
# 🧩 Q: If the academic calendar mentions exam week and the hostel rules restrict late-night entry during that time, what options does a student have for overnight study?
# 💬 I don't know. The provided context does not mention any specific rules or options for overnight study during exam week. However, it does mention that students are expected to keep their rooms clean and that hostel authorities have the right to enter and inspect rooms anytime.
# 📚 ['hostelregulations.pdf:12', 'hostelregulations.pdf:17', 'hostelregulations.pdf:2', 'I found the _Hostel Rules & Regulations_ for RGIPT Jais. HereΓÇÖs a summary of the key points_.txt:1']
# ...
